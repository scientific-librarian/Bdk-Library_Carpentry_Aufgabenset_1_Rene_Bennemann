# %%
import urllib.request
import pandas as pd
import csv

# %%
csv = pd.read_csv(r"C:\Users\Rene\Desktop\Library_Usage_Liste.csv")

# %%
csv.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT             1092             761
# 1                 0                  ADULT                0               0
# 2                 0                  ADULT               31              22
# 3                 0                  ADULT                0               0
# 4                 0                  ADULT                0               0
#
#         Age Range Home Library Code Home Library Definition  \
# 0  60 to 64 years                M6                 Mission
# 1  20 to 24 years                P1                    Park
# 2  25 to 34 years                S7                  Sunset
# 3  45 to 54 years                P1                    Park
# 4  25 to 34 years                 X            Main Library
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %%
csv.keys()
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
print(csv)
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT             1092
# 1                      0                  ADULT                0
# 2                      0                  ADULT               31
# 3                      0                  ADULT                0
# 4                      0                  ADULT                0
# 5                      0                  ADULT              126
# 6                      3                 SENIOR                0
# 7                      0                  ADULT             3002
# 8                      0                  ADULT                4
# 9                      0                  ADULT               20
# 10                     0                  ADULT                3
# 11                     0                  ADULT              102
# 12                     0                  ADULT                0
# ...

# %%
#Fragestellung 1, Thema Seniorenaktiviät: Zeige mir alle Benutzer ab 75 Jahren die Ihren Bibliotheksausweis erneuert haben.

# %%
Senior = csv[csv["Age Range"] == "75 years and over"]
Bibliotheksausweis_Erneuerung = csv[csv["Total Renewals"] >= 1]
Senioren_Verlängerungen = pd.merge(Senior, Bibliotheksausweis_Erneuerung)
#Senioren_Verlängerungen.head()
print(Senioren_Verlängerungen)
# Out:
#       Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                    3                 SENIOR              838
# 1                    3                 SENIOR               65
# 2                    3                 SENIOR              122
# 3                    3                 SENIOR              222
# 4                    3                 SENIOR              487
# 5                    3                 SENIOR                7
# 6                    3                 SENIOR               43
# 7                    3                 SENIOR              662
# 8                    3                 SENIOR               42
# 9                    3                 SENIOR              203
# 10                   3                 SENIOR              172
# 11                   3                 SENIOR              408
# 12                   3                 SENIOR              675
# 13                   3                 SENIOR                1
# ...

# %%
#Fragestellung 2 Thema Standortanaylse: Wie viele Ausleihen gab es von Nutzern in der Zentralbibliothek?

# %%
Zentralbibliothek = csv[csv["Home Library Definition"] == "Main Library"]
Ausleihen = csv[csv["Total Checkouts"] >= 1]
Zentralbibliothek_Ausleihen = pd.merge(Zentralbibliothek, Ausleihen)
Zentralbibliothek_Ausleihen.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT                1               0
# 1                 0                  ADULT                1               0
# 2                 0                  ADULT                1               0
# 3                 0                  ADULT                1               0
# 4                 0                  ADULT                1               0
#
#         Age Range Home Library Code Home Library Definition  \
# 0  60 to 64 years                 X            Main Library
# 1  60 to 64 years                 X            Main Library
# 2  60 to 64 years                 X            Main Library
# 3  60 to 64 years                 X            Main Library
# 4  60 to 64 years                 X            Main Library
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...
